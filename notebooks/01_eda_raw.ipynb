# %%
import numpy as np
import matplotlib.pyplot as plt
from brainvision.constants import *
from brainvision.data import load_patient

# %% [markdown]
# ## Exploratory Data Analysis

# %%
def collect_eda_stats(all_zips: list) -> list[dict]:
    """
    Load each patient one at a time, extract lightweight EDA statistics,
    then discard the raw cube to free memory.

    Returns a list of stat dicts — one per patient — containing only
    the aggregated arrays needed for EDA (no raw cubes retained).
    """
    stats = []
    print(f"Collecting EDA stats for {len(all_zips)} patients...\n")
    print(f"{'ID':<12} {'Shape':<22} {'DN Min':>8} {'DN Max':>8} {'NaN':>6} {'Inf':>6}")
    print("─" * 65)

    for z in all_zips:
        p   = load_patient(str(z))
        raw = p['raw']
        B   = raw.shape[2]

        # Class spectra — only for classes present in this patient
        flat_px     = raw.reshape(-1, B).astype(np.float32) # (H x W, B)
        flat_labels = p['labels'].reshape(-1) # (H x W, )
        class_spectra = {
            c: flat_px[flat_labels == c].mean(axis=0)
            for c in [1, 2, 3, 4]
            if (flat_labels == c).sum() > 0
        }

        # Class pixel counts
        class_counts = {
            c: int((flat_labels == c).sum())
            for c in [0, 1, 2, 3, 4]
        }

        stat = {
            'id':            p['id'],
            'raw_shape':     raw.shape,
            'mean_per_band': flat_px.mean(axis=0),
            'dark_mean':     p['dark'].reshape(-1, p['dark'].shape[2]).mean(axis=0),
            'white_mean':    p['white'].reshape(-1, p['white'].shape[2]).mean(axis=0),
            'labels':        p['labels'],
            'raw_min':       float(raw.min()),
            'raw_max':       float(raw.max()),
            'has_nan':       bool(np.isnan(raw).any()),
            'has_inf':       bool(np.isinf(raw).any()),
            'class_spectra': class_spectra,                  # {class_id: (B,)}
            'class_counts':  class_counts,                   # {class_id: int}
            'image':         p['image'],
            'gt_map':        p['gt_map'],
            'campaign': next(
                (c for c, d in CAMPAIGN_DIRS.items()
                if str(z).startswith(str(d))),
                None
            ),
        }

        stats.append(stat)
        del p, raw, flat_px, flat_labels

        flag = "⚠️" if stat['has_nan'] or stat['has_inf'] else "✅"
        print(f"  {stat['id']:<12} {str(stat['raw_shape']):<22} "
              f"{stat['raw_min']:>8.1f} {stat['raw_max']:>8.1f} "
              f"{str(stat['has_nan']):>6} {str(stat['has_inf']):>6}  {flag}")

    print(f"\n✅ Stats collected for {len(stats)} patients\n")
    return stats

# %%
def check_raw_integrity(stats: list[dict]):
    """Flag any patients with NaN, Inf, or unexpected DN ranges."""
    issues = [s for s in stats if s['has_nan'] or s['has_inf']]
    if issues:
        print(f"⚠️  {len(issues)} patients with NaN/Inf: {[s['id'] for s in issues]}")
    else:
        print("✅ No NaN or Inf values across all patients")

# %%
def check_label_coverage(stats: list[dict]):
    """Report pixel counts per class per patient. Flag missing classes."""
    print(f"\n{'ID':<12} {'NT':>10} {'TT':>10} {'BV':>10} {'BG':>10}  Status")
    print("─" * 65)
    for s in stats:
        cc     = s['class_counts']
        issues = [CLASS_NAMES[c] for c in [1, 2, 3, 4] if cc.get(c, 0) == 0]
        flag   = f"⚠️  Missing: {issues}" if issues else "✅"
        print(f"  {s['id']:<12} {cc.get(1,0):>10,} {cc.get(2,0):>10,} "
              f"{cc.get(3,0):>10,} {cc.get(4,0):>10,}  {flag}")

# %%
def check_spatial_consistency(stats: list[dict]):
    """Check all patients share the same H, W, B dimensions."""
    unique_shapes = set(s['raw_shape'] for s in stats)
    print(f"Unique raw cube shapes: {unique_shapes}")
    if len(unique_shapes) == 1:
        print("✅ All patients have identical dimensions")
    else:
        print("⚠️  Inconsistent shapes:")
        for s in stats:
            print(f"  {s['id']}: {s['raw_shape']}")

# %%
def plot_raw_band_profiles(stats: list[dict], n_patients: int = None):
    """
    Plot mean raw DN per band for all/some patients.
    Highlights bands intended for removal.
    """
    n = len(stats) if n_patients is None else n_patients
    fig, ax = plt.subplots(figsize=(12, 5))

    for s in stats[:n]:
        ax.plot(s['mean_per_band'], alpha=0.7, label=s['id'])

    ax.axvspan(0,            BAND_START_IDX, alpha=0.15, color='red',   label=f'Removed (0-{BAND_START_IDX})')
    ax.axvspan(BAND_END_IDX, NUMBER_OF_BANDS,alpha=0.15, color='red',   label=f'Removed ({BAND_END_IDX}-{NUMBER_OF_BANDS})')
    ax.axvspan(BAND_START_IDX, BAND_END_IDX, alpha=0.08, color='green', label=f'Retained ({BAND_START_IDX}-{BAND_END_IDX})')

    ax.set_xlabel("Band index")
    ax.set_ylabel("Mean DN value")
    ax.set_title("Raw DN band profiles — before calibration")
    ax.legend(fontsize=8, ncol=2)
    plt.tight_layout()
    plt.show()

# %%
def plot_reference_profiles(stats: list[dict], n_patients: int = None):
    """
    Plot dark and white reference spectra.
    Dark should be near-zero; white should be high and smooth.
    """
    n = len(stats) if n_patients is None else n_patients
    fig, axes = plt.subplots(1, 2, figsize=(13, 4))

    for s in stats[:n]:
        axes[0].plot(s['dark_mean'],  alpha=0.7, label=s['id'])
        axes[1].plot(s['white_mean'], alpha=0.7, label=s['id'])

    axes[0].set_title("Dark Reference — should be near zero")
    axes[1].set_title("White Reference — should be high & smooth")
    for ax in axes:
        ax.set_xlabel("Band index")
        ax.set_ylabel("Mean DN value")
        ax.legend(fontsize=7, ncol=2)

    plt.tight_layout()
    plt.show()

# %%
def plot_raw_class_spectra(stats: list[dict], n_patients: int = None):
    """
    Mean raw DN spectrum per tissue class before any preprocessing.
    Averaged across patients for a robust view of class separability.
    """
    n        = len(stats) if n_patients is None else n_patients
    combined = {c: [] for c in [1, 2, 3, 4]}

    for s in stats[:n]:
        for c, spectrum in s['class_spectra'].items():
            combined[c].append(spectrum)

    fig, ax = plt.subplots(figsize=(11, 5))

    for c in [1, 2, 3, 4]:
        if combined[c]:
            mean = np.stack(combined[c]).mean(axis=0)
            std  = np.stack(combined[c]).std(axis=0)
            ax.plot(mean, color=CLASS_COLORS[c], label=CLASS_NAMES[c])
            ax.fill_between(range(len(mean)),
                            mean - std, mean + std,
                            alpha=0.15, color=CLASS_COLORS[c])

    ax.axvspan(0,            BAND_START_IDX, alpha=0.1, color='red')
    ax.axvspan(BAND_END_IDX, NUMBER_OF_BANDS,alpha=0.1, color='red')
    ax.set_xlabel("Band index (raw)")
    ax.set_ylabel("Mean DN")
    ax.set_title("Raw class spectral signatures — before preprocessing (mean ± std across patients)")
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
def plot_class_distribution(stats: list[dict]):
    """
    Global pixel count per class across all patients.
    Reveals class imbalance that loss functions must address.
    """
    totals = {c: sum(s['class_counts'].get(c, 0) for s in stats) for c in [1, 2, 3, 4]}
    total_px  = sum(totals.values())

    fig, ax = plt.subplots(figsize=(8, 4))
    bars = ax.bar(
        [CLASS_NAMES[c] for c in [1, 2, 3, 4]],
        [totals[c] for c in [1, 2, 3, 4]],
        color=[CLASS_COLORS[c] for c in [1, 2, 3, 4]]
    )
    for bar, c in zip(bars, [1, 2, 3, 4]):
        pct = totals[c] / total_px * 100
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                f'{pct:.1f}%', ha='center', va='bottom', fontsize=10)

    ax.set_ylabel("Total pixel count")
    ax.set_title("Global class distribution — all patients")
    plt.tight_layout()
    plt.show()

    print("\nClass pixel counts:")
    for c in [1, 2, 3, 4]:
        print(f"  {CLASS_NAMES[c]:<25}: {totals[c]:>10,}  ({totals[c]/total_px*100:.1f}%)")

# %%
def plot_label_maps(stats: list[dict], n: int = 4):
    """Display GT label map and RGB preview side by side for n patients."""
    from PIL import Image
    from matplotlib.colors import ListedColormap

    cmap   = ListedColormap(['black', '#5DCAA5', '#D85A30', '#378ADD', '#888780'])
    n      = min(n, len(stats))
    fig, axes = plt.subplots(n, 2, figsize=(8, n * 3))

    for i, s in enumerate(stats[:n]):
        axes[i, 0].imshow(np.array(Image.open(s['image']).convert('RGB')))
        axes[i, 0].set_title(f"{s['id']} — RGB")
        axes[i, 0].axis('off')

        axes[i, 1].imshow(s['labels'], cmap=cmap, vmin=0, vmax=4)
        axes[i, 1].set_title(f"{s['id']} — GT Labels")
        axes[i, 1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
from brainvision.data import all_campaigns_summary

all_campaigns_summary(CAMPAIGN_DIRS)
# Out:
# ── Campaign 1 ────────────────────────────────────────
# Campaign : ../datasets/first_campaign
#   Images   (n) : 27
#   Patients (m) : 16
#   Patient IDs  : ['004', '005', '007', '008', '010', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022']
#   Image IDs    : ['004-02', '005-01', '007-01', '008-01', '008-02', '010-03', '012-01', '012-02', '013-01', '014-01', '015-01', '016-01', '016-02', '016-03', '016-04', '016-05', '017-01', '018-01', '018-02', '019-01', '020-01', '021-01', '021-02', '021-05', '022-01', '022-02', '022-03']
#
# ── Campaign 2 ────────────────────────────────────────
# Campaign : ../datasets/second_campaign
#   Images   (n) : 24
#   Patients (m) : 10
#   Patient IDs  : ['034', '035', '036', '037', '038', '039', '040', '041', '042', '043']
#   Image IDs    : ['034-01', '034-02', '034-03', '035-01', '035-02', '036-01', '036-02', '037-01', '037-02', '037-03', '037-04', '038-01', '039-01', '039-02', '040-01', '040-02', '041-01', '041-02', '042-01', '042-02', '042-03', '043-01', '043-02', '043-04']
#
# ── Campaign 3 ────────────────────────────────────────
# Campaign : ../datasets/third_campaign
#   Images   (n) : 10
#   Patients (m) : 8
#   Patient IDs  : ['050', '051', '053', '054', '055', '056', '057', '058']
#   Image IDs    : ['050-01', '051-01', '053-01', '054-01', '055-01', '055-02', '056-01', '056-02', '057-01', '058-02']
#
# ── Combined ───────────────────────────────────────────
#   Total images   : 61
#   Total patients : 34

# %%
from brainvision.data import list_patient_zips

all_zips = []
for campaign_id in [1, 2, 3]:
    zips = list_patient_zips(data_dir=CAMPAIGN_DIRS[campaign_id])
    print(f"Campaign {campaign_id}: {len(zips)} patients")
    all_zips.extend(zips)
print(f"Total: {len(all_zips)} patients")
# Out:
# Campaign 1: 27 patients
# Campaign 2: 24 patients
# Campaign 3: 10 patients
# Total: 61 patients

# %%
eda_stats = collect_eda_stats(all_zips)
# Out:
# Collecting EDA stats for 61 patients...
#
# ID           Shape                    DN Min   DN Max    NaN    Inf
# ─────────────────────────────────────────────────────────────────
# /Users/joshua/Repositories/brain-vision/.venv/lib/python3.14/site-packages/spectral/io/envi.py:187: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.settings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)
#   004-02       (389, 345, 826)             7.0   4095.0  False  False  ✅
#   005-01       (483, 488, 826)             2.0   4095.0  False  False  ✅
#   007-01       (582, 400, 826)             6.0   4095.0  False  False  ✅
#   008-01       (460, 549, 826)             2.0   4095.0  False  False  ✅
#   008-02       (480, 553, 826)             1.0   4095.0  False  False  ✅
#   010-03       (371, 461, 826)             1.0   2560.0  False  False  ✅
#   012-01       (443, 497, 826)             4.0   4095.0  False  False  ✅
#   012-02       (445, 498, 826)             2.0   4095.0  False  False  ✅
#   013-01       (298, 253, 826)             3.0   2807.0  False  False  ✅
#   014-01       (317, 244, 826)             2.0   3867.0  False  False  ✅
#   015-01       (376, 494, 826)             2.0   4095.0  False  False  ✅
#   016-01       (335, 323, 826)             4.0   1542.0  False  False  ✅
#   016-02       (335, 326, 826)             3.0   1545.0  False  False  ✅
#   016-03       (315, 321, 826)             2.0   2598.0  False  False  ✅
#   016-04       (383, 297, 826)             2.0   3350.0  False  False  ✅
#   016-05       (414, 292, 826)             1.0   4095.0  False  False  ✅
#   017-01       (441, 399, 826)             2.0   4095.0  False  False  ✅
#   018-01       (479, 462, 826)             1.0   3281.0  False  False  ✅
#   018-02       (510, 434, 826)             3.0   4095.0  False  False  ✅
#   019-01       (601, 535, 826)             0.0   4095.0  False  False  ✅
#   020-01       (378, 330, 826)             5.0   4095.0  False  False  ✅
#   021-01       (452, 334, 826)             2.0   4095.0  False  False  ✅
#   021-02       (448, 324, 826)             3.0   4095.0  False  False  ✅
#   021-05       (433, 340, 826)             5.0   4095.0  False  False  ✅
#   022-01       (597, 527, 826)             3.0   4095.0  False  False  ✅
#   022-02       (611, 527, 826)             2.0   4095.0  False  False  ✅
#   022-03       (592, 471, 826)             2.0   4095.0  False  False  ✅
#   034-01       (319, 356, 826)             2.0   4082.0  False  False  ✅
#   034-02       (300, 342, 826)             3.0   1788.0  False  False  ✅
#   034-03       (290, 301, 826)             2.0   2247.0  False  False  ✅
#   035-01       (431, 503, 826)             4.0   4095.0  False  False  ✅
#   035-02       (312, 535, 826)             1.0   4095.0  False  False  ✅
#   036-01       (412, 324, 826)             4.0   4095.0  False  False  ✅
#   036-02       (432, 322, 826)             5.0   4095.0  False  False  ✅
#   037-01       (434, 453, 826)             5.0   4095.0  False  False  ✅
#   037-02       (315, 526, 826)             6.0   4095.0  False  False  ✅
#   037-03       (290, 422, 826)             2.0   4095.0  False  False  ✅
#   037-04       (280, 444, 826)             2.0   2365.0  False  False  ✅
#   038-01       (497, 490, 826)             3.0   4095.0  False  False  ✅
#   039-01       (415, 446, 826)             3.0   4095.0  False  False  ✅
#   039-02       (399, 439, 826)             3.0   4095.0  False  False  ✅
#   040-01       (303, 374, 826)             5.0   4095.0  False  False  ✅
#   040-02       (294, 344, 826)             5.0   4095.0  False  False  ✅
#   041-01       (449, 486, 826)             2.0   4095.0  False  False  ✅
#   041-02       (437, 488, 826)             3.0   4095.0  False  False  ✅
#   042-01       (629, 646, 826)             1.0   4095.0  False  False  ✅
#   042-02       (623, 584, 826)             1.0   4095.0  False  False  ✅
#   042-03       (650, 582, 826)             1.0   4095.0  False  False  ✅
#   043-01       (575, 543, 826)             3.0   4095.0  False  False  ✅
#   043-02       (554, 446, 826)             1.0   4095.0  False  False  ✅
#   043-04       (538, 525, 826)             2.0   4095.0  False  False  ✅
#   050-01       (565, 533, 826)             1.0   2884.0  False  False  ✅
#   051-01       (635, 617, 826)             1.0   4095.0  False  False  ✅
#   053-01       (546, 446, 826)             3.0   3900.0  False  False  ✅
#   054-01       (515, 504, 826)             1.0   4095.0  False  False  ✅
#   055-01       (397, 435, 826)             2.0   1286.0  False  False  ✅
#   055-02       (500, 349, 826)             2.0   1002.0  False  False  ✅
#   056-01       (446, 598, 826)             1.0   4095.0  False  False  ✅
#   056-02       (467, 566, 826)             2.0   4095.0  False  False  ✅
#   057-01       (440, 535, 826)             2.0   4095.0  False  False  ✅
#   058-02       (721, 752, 826)             3.0   4095.0  False  False  ✅
#
# ✅ Stats collected for 61 patients

# %%
# Data quality
check_raw_integrity(eda_stats)
check_spatial_consistency(eda_stats)
check_label_coverage(eda_stats)
# Out:
# ✅ No NaN or Inf values across all patients
# Unique raw cube shapes: {(443, 497, 826), (635, 617, 826), (460, 549, 826), (298, 253, 826), (449, 486, 826), (397, 435, 826), (399, 439, 826), (592, 471, 826), (335, 323, 826), (383, 297, 826), (510, 434, 826), (601, 535, 826), (280, 444, 826), (479, 462, 826), (300, 342, 826), (483, 488, 826), (317, 244, 826), (515, 504, 826), (611, 527, 826), (582, 400, 826), (412, 324, 826), (623, 584, 826), (565, 533, 826), (433, 340, 826), (440, 535, 826), (389, 345, 826), (554, 446, 826), (319, 356, 826), (414, 292, 826), (371, 461, 826), (448, 324, 826), (432, 322, 826), (315, 526, 826), (290, 301, 826), (378, 330, 826), (303, 374, 826), (312, 535, 826), (290, 422, 826), (538, 525, 826), (437, 488, 826), (431, 503, 826), (415, 446, 826), (650, 582, 826), (629, 646, 826), (575, 543, 826), (315, 321, 826), (445, 498, 826), (546, 446, 826), (467, 566, 826), (721, 752, 826), (335, 326, 826), (480, 553, 826), (452, 334, 826), (597, 527, 826), (500, 349, 826), (434, 453, 826), (294, 344, 826), (446, 598, 826), (441, 399, 826), (376, 494, 826), (497, 490, 826)}
# ⚠️  Inconsistent shapes:
#   004-02: (389, 345, 826)
#   005-01: (483, 488, 826)
#   007-01: (582, 400, 826)
#   008-01: (460, 549, 826)
#   008-02: (480, 553, 826)
#   010-03: (371, 461, 826)
#   012-01: (443, 497, 826)
#   012-02: (445, 498, 826)
#   013-01: (298, 253, 826)
#   014-01: (317, 244, 826)
#   015-01: (376, 494, 826)
#   016-01: (335, 323, 826)
#   016-02: (335, 326, 826)
#   016-03: (315, 321, 826)
#   016-04: (383, 297, 826)
#   016-05: (414, 292, 826)
#   017-01: (441, 399, 826)
#   018-01: (479, 462, 826)
#   018-02: (510, 434, 826)
#   019-01: (601, 535, 826)
#   020-01: (378, 330, 826)
#   021-01: (452, 334, 826)
#   021-02: (448, 324, 826)
#   021-05: (433, 340, 826)
#   022-01: (597, 527, 826)
#   022-02: (611, 527, 826)
#   022-03: (592, 471, 826)
#   034-01: (319, 356, 826)
#   034-02: (300, 342, 826)
#   034-03: (290, 301, 826)
#   035-01: (431, 503, 826)
#   035-02: (312, 535, 826)
#   036-01: (412, 324, 826)
#   036-02: (432, 322, 826)
#   037-01: (434, 453, 826)
#   037-02: (315, 526, 826)
#   037-03: (290, 422, 826)
#   037-04: (280, 444, 826)
#   038-01: (497, 490, 826)
#   039-01: (415, 446, 826)
#   039-02: (399, 439, 826)
#   040-01: (303, 374, 826)
#   040-02: (294, 344, 826)
#   041-01: (449, 486, 826)
#   041-02: (437, 488, 826)
#   042-01: (629, 646, 826)
#   042-02: (623, 584, 826)
#   042-03: (650, 582, 826)
#   043-01: (575, 543, 826)
#   043-02: (554, 446, 826)
#   043-04: (538, 525, 826)
#   050-01: (565, 533, 826)
#   051-01: (635, 617, 826)
#   053-01: (546, 446, 826)
#   054-01: (515, 504, 826)
#   055-01: (397, 435, 826)
#   055-02: (500, 349, 826)
#   056-01: (446, 598, 826)
#   056-02: (467, 566, 826)
#   057-01: (440, 535, 826)
#   058-02: (721, 752, 826)
#
# ID                   NT         TT         BV         BG  Status
# ─────────────────────────────────────────────────────────────────
#   004-02            5,007          0        965      1,992  ⚠️  Missing: ['Tumour Tissue (TT)']
#   005-01            6,061          0      1,727     20,483  ⚠️  Missing: ['Tumour Tissue (TT)']
#   007-01            7,714          0      1,089          0  ⚠️  Missing: ['Tumour Tissue (TT)', 'Background (BG)']
#   008-01            2,295      1,221      1,331        630  ✅
#   008-02            2,187        138      1,000      7,444  ✅
#   010-03           10,626          0      2,332      3,972  ⚠️  Missing: ['Tumour Tissue (TT)']
#   012-01            4,516        855      8,697      1,685  ✅
#   012-02            6,553      3,139      6,041      8,731  ✅
#   013-01            1,827          0        129        589  ⚠️  Missing: ['Tumour Tissue (TT)']
#   014-01                0          0         64      1,866  ⚠️  Missing: ['Normal Tissue (NT)', 'Tumour Tissue (TT)']
#   015-01            1,251      2,046      4,089        696  ✅
#   016-01            3,970          0        246     12,002  ⚠️  Missing: ['Tumour Tissue (TT)']
#   016-02              349          0          0      2,767  ⚠️  Missing: ['Tumour Tissue (TT)', 'Blood Vessel (BV)']
#   016-03              603          0        234      1,696  ⚠️  Missing: ['Tumour Tissue (TT)']
#   016-04            1,178          0      1,064        956  ⚠️  Missing: ['Tumour Tissue (TT)']
#   016-05            2,643          0        452      5,125  ⚠️  Missing: ['Tumour Tissue (TT)']
#   017-01            1,328          0         68      3,069  ⚠️  Missing: ['Tumour Tissue (TT)']
#   018-01           13,450          0        488      9,773  ⚠️  Missing: ['Tumour Tissue (TT)']
#   018-02            4,813          0        958      5,895  ⚠️  Missing: ['Tumour Tissue (TT)']
#   019-01            6,499          0      1,350      1,933  ⚠️  Missing: ['Tumour Tissue (TT)']
#   020-01            1,842      3,655      1,513      2,625  ✅
#   021-01            2,663        240      2,325      5,651  ✅
#   021-02            2,313         32        591      4,688  ✅
#   021-05            1,038          0        587     10,187  ⚠️  Missing: ['Tumour Tissue (TT)']
#   022-01            2,806          0      1,064      3,677  ⚠️  Missing: ['Tumour Tissue (TT)']
#   022-02            8,174          0        680          0  ⚠️  Missing: ['Tumour Tissue (TT)', 'Background (BG)']
#   022-03                0         96          0          0  ⚠️  Missing: ['Normal Tissue (NT)', 'Blood Vessel (BV)', 'Background (BG)']
#   034-01                0          0          0     15,609  ⚠️  Missing: ['Normal Tissue (NT)', 'Tumour Tissue (TT)', 'Blood Vessel (BV)']
#   034-02              512        145          0     12,979  ⚠️  Missing: ['Blood Vessel (BV)']
#   034-03                0        360          0     10,533  ⚠️  Missing: ['Normal Tissue (NT)', 'Blood Vessel (BV)']
#   035-01            9,025          0      7,287        485  ⚠️  Missing: ['Tumour Tissue (TT)']
#   035-02                0      1,338        629      1,353  ⚠️  Missing: ['Normal Tissue (NT)']
#   036-01           11,665          0      4,461      4,621  ⚠️  Missing: ['Tumour Tissue (TT)']
#   036-02            2,940        888      2,980      5,853  ✅
#   037-01           12,719          0      2,524     11,161  ⚠️  Missing: ['Tumour Tissue (TT)']
#   037-02            2,997          0        375      4,166  ⚠️  Missing: ['Tumour Tissue (TT)']
#   037-03            3,201        407          0          0  ⚠️  Missing: ['Blood Vessel (BV)', 'Background (BG)']
#   037-04                0        330          0          0  ⚠️  Missing: ['Normal Tissue (NT)', 'Blood Vessel (BV)', 'Background (BG)']
#   038-01           18,511      2,295      4,229      3,669  ✅
#   039-01            4,003        244        489      9,829  ✅
#   039-02            7,705      1,629        822      9,867  ✅
#   040-01            2,728        394      1,151      3,492  ✅
#   040-02              817        700      2,130        902  ✅
#   041-01            2,359         69      1,047      5,030  ✅
#   041-02            4,874        158      2,150      4,888  ✅
#   042-01           20,565          0     10,956      8,991  ⚠️  Missing: ['Tumour Tissue (TT)']
#   042-02           19,435        428      5,110      3,983  ✅
#   042-03            2,385        401        979        716  ✅
#   043-01           28,285      1,177      4,012      5,995  ✅
#   043-02           17,236        475      2,103      1,964  ✅
#   043-04           14,160          0      4,749        687  ⚠️  Missing: ['Tumour Tissue (TT)']
#   050-01            2,116      1,091        620      5,502  ✅
#   051-01            1,164          0        424     31,247  ⚠️  Missing: ['Tumour Tissue (TT)']
#   053-01              361      5,549          0     33,606  ⚠️  Missing: ['Blood Vessel (BV)']
#   054-01            2,697          0      3,506      9,535  ⚠️  Missing: ['Tumour Tissue (TT)']
#   055-01            3,128          0        901      8,278  ⚠️  Missing: ['Tumour Tissue (TT)']
#   055-02                0      1,046        545      9,415  ⚠️  Missing: ['Normal Tissue (NT)']
#   056-01            1,346      4,081      2,200     28,370  ✅
#   056-02            1,326        372      1,116      7,702  ✅
#   057-01            1,773        771      1,263     23,415  ✅
#   058-02            6,589      1,629      4,565     43,565  ✅

# %%
# Sensor behaviour
plot_raw_band_profiles(eda_stats)
plot_reference_profiles(eda_stats)

# %%
# Class behaviour
plot_raw_class_spectra(eda_stats)
plot_class_distribution(eda_stats)
plot_label_maps(eda_stats, n=2)
# Out:
# Class pixel counts:
#   Normal Tissue (NT)       :    308,328  (34.1%)
#   Tumour Tissue (TT)       :     37,399  (4.1%)
#   Blood Vessel (BV)        :    112,407  (12.4%)
#   Background (BG)          :    445,540  (49.3%)
